# %%
# !pip install markovify
# Out:
# Collecting markovify
#   Downloading markovify-0.9.4.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Collecting unidecode (from markovify)
#   Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 6.3 MB/s eta 0:00:00
# Building wheels for collected packages: markovify
#   Building wheel for markovify (setup.py) ... done
#   Created wheel for markovify: filename=markovify-0.9.4-py3-none-any.whl size=18608 sha256=de3f01db98099c6682d010764d32d2476d0765f57111164c32496612fe57b8a6
#   Stored in directory: /root/.cache/pip/wheels/ca/8c/c5/41413e24c484f883a100c63ca7b3b0362b7c6f6eb6d7c9cc7f
# Successfully built markovify
# Installing collected packages: unidecode, markovify
# Successfully installed markovify-0.9.4 unidecode-1.3.8

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import markovify #Markov Chain Generator

# %%
inp = pd.read_csv('abcnews-date-text.csv')

# %%
inp
# Out:
#         publish_date                                      headline_text
# 0           20030219  aba decides against community broadcasting lic...
# 1           20030219     act fire witnesses must be aware of defamation
# 2           20030219     a g calls for infrastructure protection summit
# 3           20030219           air nz staff in aust strike for pay rise
# 4           20030219      air nz strike to affect australian travellers
# ...              ...                                                ...
# 383456      20080514        many households unprepared for disaster abs
# 383457      20080514               maroons selectors defend hunt gamble
# 383458      20080514          mayor defends decision to dump exhibition
# 383459      20080514                mbf bupa merger gets court go ahead
# 383460      20080514          mccain allied preacher apologises over ca
#
# [383461 rows x 2 columns]

# %%
text_model = markovify.NewlineText(inp.headline_text, state_size = 2)

# %%
# Print ten randomly-generated sentences using the built model
for i in range(10):
    print(text_model.make_sentence())
# Out:
# pm should release fair pay
# narrabundah land swap deal
# germans fear first european group race
# downer calls for police
# govt urged to crack down on business ban
# raikkonen owns up to control protests
# total fire ban continues
# esplanade ceremony commemorates coral sea plans a political stunt entsch
# nt ahead of full on
# pm rejects calls for unbiased govt funded pregnancy
